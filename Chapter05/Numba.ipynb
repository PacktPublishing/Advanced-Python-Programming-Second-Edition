# %% [markdown]
# # First steps with Numba

# %%
import numba as nb
import numpy as np

# %%
@nb.jit(nopython=True)
def sum_sq(a):
    N = len(a)
    
    result = 0
    for i in range(N):
        result += a[i] ** 2
    
    return result

# %%
x = np.random.rand(10000)

# %%
# %timeit sum_sq.py_func(x)
# Out:
# 100 loops, best of 3: 3.85 ms per loop

# %%
# %timeit sum_sq(x)
# Out:
# The slowest run took 5773.33 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100000 loops, best of 3: 11.6 µs per loop

# %%
# %timeit (x**2).sum()
# Out:
# The slowest run took 44.19 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10000 loops, best of 3: 14.8 µs per loop

# %%
x_list = x.tolist()

# %%
# %timeit sum_sq(x_list)
# Out:
# The slowest run took 523.66 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000 loops, best of 3: 199 µs per loop

# %%
# %timeit sum([x**2 for x in x_list])
# Out:
# 1000 loops, best of 3: 1.28 ms per loop

# %% [markdown]
# ## Type specializations

# %%
sum_sq.signatures
# Out:
# []

# %%
x = np.random.rand(1000).astype('float64')
sum_sq(x)
sum_sq.signatures
# Out:
# [(array(float64, 1d, A),)]

# %%
x = np.random.rand(10000).astype('float32')
sum_sq(x)
sum_sq.signatures
# Out:
# [(array(float64, 1d, A),)]

# %%
@nb.jit(['float64(float64[:])',
         'float32(float32[:])'])
def sum_sq(a):
    N = len(a)
    
    result = 0
    for i in range(N):
        result += a[i] ** 2
    
    return result

# %%
sum_sq.signatures
# Out:
# [(array(float64, 1d, A),), (array(float32, 1d, A),)]

# %%
sum_sq.inspect_types()
# Out:
# sum_sq (array(float64, 1d, A),)
# --------------------------------------------------------------------------------
# # File: <ipython-input-41-40dcde0acb08>
# # --- LINE 1 ---
# # label 0
# #   del $0.1
# #   del $0.3
# #   del $const0.4
#
# @nb.jit(['float64(float64[:])',
#
#          # --- LINE 2 ---
#
#          'float32(float32[:])'])
#
# # --- LINE 3 ---
#
# def sum_sq(a):
#
#     # --- LINE 4 ---
#     #   a = arg(0, name=a)  :: array(float64, 1d, A)
#     #   $0.1 = global(len: <built-in function len>)  :: Function(<built-in function len>)
#     #   $0.3 = call $0.1(a)  :: (array(float64, 1d, A),) -> int64
#     #   N = $0.3  :: int64
#
#     N = len(a)
#
# # --- LINE 5 ---
#
#
#
#     # --- LINE 6 ---
#     #   $const0.4 = const(int, 0)  :: int64
#     #   result = $const0.4  :: float64
#     #   jump 18
#     # label 18
#
#     result = 0
#
#     # --- LINE 7 ---
#     #   jump 21
#     # label 21
#     #   $21.1 = global(range: <class 'range'>)  :: Function(<class 'range'>)
#     #   $21.3 = call $21.1(N)  :: (int64,) -> range_state_int64
#     #   del N
#     #   del $21.1
#     #   $21.4 = getiter(value=$21.3)  :: range_iter_int64
#     #   del $21.3
#     #   $phi31.1 = $21.4  :: range_iter_int64
#     #   del $21.4
#     #   jump 31
#     # label 31
#     #   $31.2 = iternext(value=$phi31.1)  :: pair<int64, bool>
#     #   $31.3 = pair_first(value=$31.2)  :: int64
#     #   $31.4 = pair_second(value=$31.2)  :: bool
#     #   del $31.2
#     #   $phi34.1 = $31.3  :: int64
#     #   del $31.3
#     #   branch $31.4, 34, 58
#     # label 34
#     #   del $31.4
#     #   i = $phi34.1  :: int64
#     #   del $phi34.1
#     #   del i
#     #   del $const34.6
#     #   del $34.5
#     #   del $34.7
#     #   del $34.8
#
#     for i in range(N):
#
#         # --- LINE 8 ---
#         #   $34.5 = getitem(index=i, value=a)  :: float64
#         #   $const34.6 = const(int, 2)  :: int64
#         #   $34.7 = $34.5 ** $const34.6  :: float64
#         #   $34.8 = inplace_binop(immutable_fn=+, rhs=$34.7, fn=+=, static_rhs=<object object at 0x7f99679943c0>, static_lhs=<object object at 0x7f99679943c0>, lhs=result)  :: float64
#         #   result = $34.8  :: float64
#         #   jump 31
#         # label 58
#         #   del a
#         #   del $phi34.1
#         #   del $phi31.1
#         #   del $31.4
#         #   jump 59
#         # label 59
#         #   del result
#
#         result += a[i] ** 2
#
# # --- LINE 9 ---
#
#
#
#     # --- LINE 10 ---
#     #   $59.2 = cast(value=result)  :: float64
#     #   return $59.2
#
#     return result
#
#
# ================================================================================
# sum_sq (array(float32, 1d, A),)
# --------------------------------------------------------------------------------
# # File: <ipython-input-41-40dcde0acb08>
# # --- LINE 1 ---
# # label 0
# #   del $0.1
# #   del $0.3
# #   del $const0.4
#
# @nb.jit(['float64(float64[:])',
#
#          # --- LINE 2 ---
#
#          'float32(float32[:])'])
#
# # --- LINE 3 ---
#
# def sum_sq(a):
#
#     # --- LINE 4 ---
#     #   a = arg(0, name=a)  :: array(float32, 1d, A)
#     #   $0.1 = global(len: <built-in function len>)  :: Function(<built-in function len>)
#     #   $0.3 = call $0.1(a)  :: (array(float32, 1d, A),) -> int64
#     #   N = $0.3  :: int64
#
#     N = len(a)
#
# # --- LINE 5 ---
#
#
#
#     # --- LINE 6 ---
#     #   $const0.4 = const(int, 0)  :: int64
#     #   result = $const0.4  :: float64
#     #   jump 18
#     # label 18
#
#     result = 0
#
#     # --- LINE 7 ---
#     #   jump 21
#     # label 21
#     #   $21.1 = global(range: <class 'range'>)  :: Function(<class 'range'>)
#     #   $21.3 = call $21.1(N)  :: (int64,) -> range_state_int64
#     #   del N
#     #   del $21.1
#     #   $21.4 = getiter(value=$21.3)  :: range_iter_int64
#     #   del $21.3
#     #   $phi31.1 = $21.4  :: range_iter_int64
#     #   del $21.4
#     #   jump 31
#     # label 31
#     #   $31.2 = iternext(value=$phi31.1)  :: pair<int64, bool>
#     #   $31.3 = pair_first(value=$31.2)  :: int64
#     #   $31.4 = pair_second(value=$31.2)  :: bool
#     #   del $31.2
#     #   $phi34.1 = $31.3  :: int64
#     #   del $31.3
#     #   branch $31.4, 34, 58
#     # label 34
#     #   del $31.4
#     #   i = $phi34.1  :: int64
#     #   del $phi34.1
#     #   del i
#     #   del $const34.6
#     #   del $34.5
#     #   del $34.7
#     #   del $34.8
#
#     for i in range(N):
#
#         # --- LINE 8 ---
#         #   $34.5 = getitem(index=i, value=a)  :: float32
#         #   $const34.6 = const(int, 2)  :: int64
#         #   $34.7 = $34.5 ** $const34.6  :: float32
#         #   $34.8 = inplace_binop(immutable_fn=+, rhs=$34.7, fn=+=, static_rhs=<object object at 0x7f99679943c0>, static_lhs=<object object at 0x7f99679943c0>, lhs=result)  :: float64
#         #   result = $34.8  :: float64
#         #   jump 31
#         # label 58
#         #   del a
#         #   del $phi34.1
#         #   del $phi31.1
#         #   del $31.4
#         #   jump 59
#         # label 59
#         #   del result
#
#         result += a[i] ** 2
#
# # --- LINE 9 ---
#
#
#
#     # --- LINE 10 ---
#     #   $59.2 = cast(value=result)  :: float32
#     #   return $59.2
#
#     return result
#
#
# ================================================================================

# %%
@nb.jit
def concatenate(strings):
    result = ''
    for s in strings:
        result += s
    return result

# %%
concatenate(['hello', 'world'])
concatenate.signatures
concatenate.inspect_types()
# Out:
# concatenate (reflected list(str),)
# --------------------------------------------------------------------------------
# # File: <ipython-input-45-a826ad379539>
# # --- LINE 1 ---
# # label 0
# #   del $const0.1
#
# @nb.jit
#
# # --- LINE 2 ---
#
# def concatenate(strings):
#
#     # --- LINE 3 ---
#     #   strings = arg(0, name=strings)  :: pyobject
#     #   $const0.1 = const(str, )  :: pyobject
#     #   result = $const0.1  :: pyobject
#     #   jump 6
#     # label 6
#
#     result = ''
#
#     # --- LINE 4 ---
#     #   jump 9
#     # label 9
#     #   $17 = const(LiftedLoop, LiftedLoop(<function concatenate at 0x7f9939c032f0>))  :: XXX Lifted Loop XXX
#     #   $18 = call $17(result, strings)  :: XXX Lifted Loop XXX
#     #   del strings
#     #   del $17
#     #   result = static_getitem(index_var=None, index=0, value=$18)  :: pyobject
#     #   del $18
#     #   jump 33
#
#     for s in strings:
#
#         # --- LINE 5 ---
#         # label 33
#         #   del result
#
#         result += s
#
#     # --- LINE 6 ---
#     #   $33.2 = cast(value=result)  :: pyobject
#     #   return $33.2
#
#     return result
#
# # The function contains lifted loops
# # Loop at line 4
# # Has 1 overloads
# # File: <ipython-input-45-a826ad379539>
# # --- LINE 1 ---
#
# @nb.jit
#
# # --- LINE 2 ---
#
# def concatenate(strings):
#
#     # --- LINE 3 ---
#
#     result = ''
#
#     # --- LINE 4 ---
#     # label 8
#     #   result = arg(0, name=result)  :: pyobject
#     #   strings = arg(1, name=strings)  :: pyobject
#     #   jump 9
#     # label 9
#     #   $9.2 = getiter(value=strings)  :: pyobject
#     #   del strings
#     #   $phi13.1 = $9.2  :: pyobject
#     #   del $9.2
#     #   jump 13
#     # label 13
#     #   $13.2 = iternext(value=$phi13.1)  :: pyobject
#     #   $13.3 = pair_first(value=$13.2)  :: pyobject
#     #   $13.4 = pair_second(value=$13.2)  :: pyobject
#     #   del $13.2
#     #   $phi16.1 = $13.3  :: pyobject
#     #   del $13.3
#     #   branch $13.4, 16, 32
#     # label 16
#     #   del $13.4
#     #   s = $phi16.1  :: pyobject
#     #   del $phi16.1
#     #   del s
#     #   del $16.4
#     # label 33
#     #   $16 = build_tuple(items=[Var(result, <ipython-input-45-a826ad379539> (3))])  :: pyobject
#     #   del result
#     #   return $16
#
#     for s in strings:
#
#         # --- LINE 5 ---
#         #   $16.4 = inplace_binop(immutable_fn=+, rhs=s, fn=+=, static_rhs=<object object at 0x7f99679943c0>, static_lhs=<object object at 0x7f99679943c0>, lhs=result)  :: pyobject
#         #   result = $16.4  :: pyobject
#         #   jump 13
#         # label 32
#         #   del $phi16.1
#         #   del $phi13.1
#         #   del $13.4
#         #   jump 33
#
#         result += s
#
#     # --- LINE 6 ---
#
#     return result
#
#
#
# ================================================================================

# %%
x = ['hello'] * 1000
# %timeit concatenate.py_func(x)
# Out:
# 10000 loops, best of 3: 111 µs per loop

# %%
# %timeit concatenate(x)
# Out:
# 1000 loops, best of 3: 317 µs per loop

# %%
# Strings are mostly unsupported in nopython mode

@nb.jit(nopython=True)
def concatenate(strings):
    result = ''
    for s in strings:
        result += s
    return result

concatenate(x)
# Out:
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# <ipython-input-53-aa35a1ec2403> in <module>()
#       5         result += s
#       6     return result
# ----> 7 concatenate(x)
#
# /home/gabriele/anaconda/envs/hperf/lib/python3.5/site-packages/numba/dispatcher.py in _compile_for_args(self, *args, **kws)
#     307                                 for i, err in failed_args))
#     308                 e.patch_message(msg)
# --> 309             raise e
#     310
#     311     def inspect_llvm(self, signature=None):
#
# /home/gabriele/anaconda/envs/hperf/lib/python3.5/site-packages/numba/dispatcher.py in _compile_for_args(self, *args, **kws)
#     284                 argtypes.append(self.typeof_pyval(a))
#     285         try:
# --> 286             return self.compile(tuple(argtypes))
#     287         except errors.TypingError as e:
#     288             # Intercept typing error that may be due to an argument
#
# /home/gabriele/anaconda/envs/hperf/lib/python3.5/site-packages/numba/dispatcher.py in compile(self, sig)
#     530
#     531             self._cache_misses[sig] += 1
# --> 532             cres = self._compiler.compile(args, return_type)
#     533             self.add_overload(cres)
#     534             self._cache.save_overload(sig, cres)
#
# /home/gabriele/anaconda/envs/hperf/lib/python3.5/site-packages/numba/dispatcher.py in compile(self, args, return_type)
#      79                                       impl,
#      80                                       args=args, return_type=return_type,
# ---> 81                                       flags=flags, locals=self.locals)
#      82         # Check typing error if object mode is used
#      83         if cres.typing_error is not None and not flags.enable_pyobject:
#
# /home/gabriele/anaconda/envs/hperf/lib/python3.5/site-packages/numba/compiler.py in compile_extra(typingctx, targetctx, func, args, return_type, flags, locals, library)
#     691     pipeline = Pipeline(typingctx, targetctx, library,
#     692                         args, return_type, flags, locals)
# --> 693     return pipeline.compile_extra(func)
#     694
#     695
#
# /home/gabriele/anaconda/envs/hperf/lib/python3.5/site-packages/numba/compiler.py in compile_extra(self, func)
#     348         self.lifted = ()
#     349         self.lifted_from = None
# --> 350         return self._compile_bytecode()
#     351
#     352     def compile_ir(self, func_ir, lifted=(), lifted_from=None):
#
# /home/gabriele/anaconda/envs/hperf/lib/python3.5/site-packages/numba/compiler.py in _compile_bytecode(self)
#     656         """
#     657         assert self.func_ir is None
# --> 658         return self._compile_core()
#     659
#     660     def _compile_ir(self):
#
# /home/gabriele/anaconda/envs/hperf/lib/python3.5/site-packages/numba/compiler.py in _compile_core(self)
#     643
#     644         pm.finalize()
# --> 645         res = pm.run(self.status)
#     646         if res is not None:
#     647             # Early pipeline completion
#
# /home/gabriele/anaconda/envs/hperf/lib/python3.5/site-packages/numba/compiler.py in run(self, status)
#     234                     # No more fallback pipelines?
#     235                     if is_final_pipeline:
# --> 236                         raise patched_exception
#     237                     # Go to next fallback pipeline
#     238                     else:
#
# /home/gabriele/anaconda/envs/hperf/lib/python3.5/site-packages/numba/compiler.py in run(self, status)
#     226                 try:
#     227                     event(stage_name)
# --> 228                     stage()
#     229                 except _EarlyPipelineCompletion as e:
#     230                     return e.result
#
# /home/gabriele/anaconda/envs/hperf/lib/python3.5/site-packages/numba/compiler.py in stage_nopython_frontend(self)
#     440                 self.args,
#     441                 self.return_type,
# --> 442                 self.locals)
#     443
#     444         with self.fallback_context('Function "%s" has invalid return type'
#
# /home/gabriele/anaconda/envs/hperf/lib/python3.5/site-packages/numba/compiler.py in type_inference_stage(typingctx, interp, args, return_type, locals)
#     792
#     793         infer.build_constraint()
# --> 794         infer.propagate()
#     795         typemap, restype, calltypes = infer.unify()
#     796
#
# /home/gabriele/anaconda/envs/hperf/lib/python3.5/site-packages/numba/typeinfer.py in propagate(self, raise_errors)
#     765         if errors:
#     766             if raise_errors:
# --> 767                 raise errors[0]
#     768             else:
#     769                 return errors
#
# /home/gabriele/anaconda/envs/hperf/lib/python3.5/site-packages/numba/typeinfer.py in propagate(self, typeinfer)
#     126                                                    lineno=loc.line):
#     127                 try:
# --> 128                     constraint(typeinfer)
#     129                 except TypingError as e:
#     130                     errors.append(e)
#
# /home/gabriele/anaconda/envs/hperf/lib/python3.5/site-packages/numba/typeinfer.py in __call__(self, typeinfer)
#     435     def __call__(self, typeinfer):
#     436         with new_error_context("typing of intrinsic-call at {0}", self.loc):
# --> 437             self.resolve(typeinfer, typeinfer.typevars, fnty=self.func)
#     438
#     439
#
# /home/gabriele/anaconda/envs/hperf/lib/python3.5/site-packages/numba/typeinfer.py in resolve(self, typeinfer, typevars, fnty)
#     399             desc = context.explain_function_type(fnty)
#     400             msg = '\n'.join([head, desc])
# --> 401             raise TypingError(msg, loc=self.loc)
#     402
#     403         typeinfer.add_type(self.target, sig.return_type, loc=self.loc)
#
# TypingError: Failed at nopython (nopython frontend)
# Invalid usage of += with parameters (const(''), str)
#  * parameterized
# File "<ipython-input-53-aa35a1ec2403>", line 5
# [1] During: typing of intrinsic-call at <ipython-input-53-aa35a1ec2403> (5)

# %% [markdown]
# # Ufuncs and Gufuncs

# %%
# Numpy vectorization
@np.vectorize
def cantor_py(a, b):
    return  int(0.5 * (a + b)*(a + b + 1) + b)

# %%
cantor_py(np.array([1, 2]), 2)
# Out:
# array([ 8, 12])

# %%
# Numba vectorization
@nb.vectorize
def cantor(a, b):
    return  int(0.5 * (a + b)*(a + b + 1) + b)

# %%
cantor(np.array([1, 2]), 2)
# Out:
# array([ 8, 12])

# %%
x1 = np.random.rand(10000)
x2 = np.random.rand(10000)

# %%
# %timeit cantor_py(x1, x2)
# Out:
# 100 loops, best of 3: 6.06 ms per loop

# %%
# %timeit cantor(x1, x2)
# Out:
# The slowest run took 3871.58 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100000 loops, best of 3: 15 µs per loop

# %%
# %timeit (0.5 * (x1 + x2)*(x1 + x2 + 1) + x2).astype(int)
# Out:
# The slowest run took 6.92 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10000 loops, best of 3: 57.1 µs per loop

# %% [markdown]
# # Matrix multiplication

# %%
a = np.random.rand(3, 3)
b = np.random.rand(3, 3)

c = np.matmul(a, b)
c.shape
# Out:
# (3, 3)

# %%
a = np.random.rand(10, 3, 3)
b = np.random.rand(10, 3, 3)

c = np.matmul(a, b)
c.shape

np.allclose(np.matmul(a[0], b[0]), c[0])
# Out:
# True

# %%
a = np.random.rand(10, 3, 3)
b = np.random.rand(3, 3)
c = np.matmul(a, b)
c.shape
# Out:
# (10, 3, 3)

# %%
@nb.guvectorize(['float64[:], float64[:], float64[:]'], '(n), (n) -> ()')
def euclidean(a, b, out):
    N = a.shape[0]
    out[0] = 0
    for i in range(N):
        out[0] += (a[i] - b[i])**2

# %%
a = np.random.rand(2)
b = np.random.rand(2)
c = euclidean(a, b)

a = np.random.rand(10, 2)
b = np.random.rand(10, 2)
c = euclidean(a, b)

a = np.random.rand(10, 2)
b = np.random.rand(2)
c = euclidean(a, b)

# %%
a = np.random.rand(10000, 2)
b = np.random.rand(10000, 2)

# %%
# %timeit ((a - b)**2).sum(axis=1)
# Out:
# The slowest run took 8.33 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000 loops, best of 3: 200 µs per loop

# %%
# %timeit euclidean(a, b)
# Out:
# 10000 loops, best of 3: 36.2 µs per loop

# %%
np.allclose(((a - b)**2).sum(axis=1), euclidean(a, b))
# Out:
# True

# %% [markdown]
# # JIT classes

# %%
class Node:
    def __init__(self, value):
        self.next = None
        self.value = value


class LinkedList:
    
    def __init__(self):
        self.head = None
    
    def push_front(self, value):
        if self.head == None:
            self.head = Node(value)
        else:
            # We replace the head
            new_head = Node(value)
            new_head.next = self.head
            self.head = new_head
    
    def show(self):
        node = self.head
        while node is not None:
            print(node.value)
            node = node.next
@nb.jit   
def sum_list(lst):
    result = 0
    node = lst.head
    while node is not None:
        result += node.value
        node = node.next
    return result
        
lst = LinkedList()
lst.push_front(1)
lst.push_front(2)
lst.push_front(3)
lst.show()

sum_list(lst)
# Out:
# 3
# 2
# 1
# 6

# %%
lst = LinkedList()
[lst.push_front(i) for i in range(10000)]

# %timeit sum_list(lst)
# %timeit sum_list.py_func(lst)
# Out:
# 100 loops, best of 3: 1.75 ms per loop
# 1000 loops, best of 3: 2.36 ms per loop

# %%
node_type = nb.deferred_type()

node_spec = [
    ('next', nb.optional(node_type)),
    ('value', nb.int64)
]

@nb.jitclass(node_spec)
class Node:
    def __init__(self, value):
        self.next = None
        self.value = value

node_type.define(Node.class_type.instance_type)


ll_spec = [
    ('head', nb.optional(Node.class_type.instance_type))
]

@nb.jitclass(ll_spec)
class LinkedList:
    
    def __init__(self):
        self.head = None
    
    def push_front(self, value):
        if self.head is None:
            self.head = Node(value)
        else:
            # We replace the head
            new_head = Node(value)
            new_head.next = self.head
            self.head = new_head
    
    def show(self):
        node = self.head
        while node is not None:
            print(node.value)
            node = node.next


lst = LinkedList()
lst.push_front(1)
lst.push_front(2)
lst.push_front(3)
lst.show()
# Out:
# 3
# 2
# 1

# %%
lst = LinkedList()
[lst.push_front(i) for i in range(10000)]

# %timeit sum_list(lst)
# %timeit sum_list.py_func(lst)
# Out:
# The slowest run took 128.84 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000 loops, best of 3: 345 µs per loop
# 100 loops, best of 3: 3.36 ms per loop

# %% [markdown]
# # Tips and Tricks

# %%
a = [[0, 1, 2], 
      [3, 4], 
      [5, 6, 7, 8]]

@nb.jit
def sum_sublists(a):
    result = [0]

    for sublist in a:
        result.append(sum(sublist))
    
    return result[1:]

sum_sublists(a)
# Out:
# [3, 7, 26]
